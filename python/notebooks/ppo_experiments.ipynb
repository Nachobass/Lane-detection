# %% [markdown]
# # PPO on Unity Lane Simulator
#
# This notebook connects to the Unity TCP bridge and trains PPO while plotting rewards.

# %%
# !pip install stable_baselines3
import os
import numpy as np
import matplotlib.pyplot as plt
from stable_baselines3 import PPO
import sys, os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from rl_bridge.envs import make_env

HOST = "127.0.0.1"
PORT = 5555
LOGDIR = "runs/ppo_lane"
TIMESTEPS = 50_000

os.makedirs(LOGDIR, exist_ok=True)

env = make_env(HOST, PORT)
obs, _ = env.reset()
print("Obs shape:", obs.shape)

model = PPO(
    "MlpPolicy", env, verbose=1, tensorboard_log=LOGDIR,
    n_steps=1024, batch_size=256, gae_lambda=0.95, gamma=0.995, n_epochs=10,
    learning_rate=3e-4, clip_range=0.2,
)

rewards = []

def callback(_locals, _globals):
    # placeholder; SB3 callbacks differ here when using learn()
    return True

model.learn(total_timesteps=TIMESTEPS)

env.close()
print("Training finished.")
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# Cell In[1], line 19
#      16 os.makedirs(LOGDIR, exist_ok=True)
#      18 env = make_env(HOST, PORT)
# ---> 19 obs, _ = env.reset()
#      20 print("Obs shape:", obs.shape)
#      22 model = PPO(
#      23     "MlpPolicy", env, verbose=1, tensorboard_log=LOGDIR,
#      24     n_steps=1024, batch_size=256, gae_lambda=0.95, gamma=0.995, n_epochs=10,
#      25     learning_rate=3e-4, clip_range=0.2,
#      26 )
#
# File ~/Documents/Escuela/Udesa/3er año/2do semestre/RL/Tps/Lane-detection/python/rl_bridge/envs/unity_lane_env.py:70, in UnityLaneEnv.reset(self, seed, options)
#      68 super().reset(seed=seed)
#      69 self._connect()
# ---> 70 data = self._send({"cmd": "reset"})
#      71 obs = np.array(data["obs"], dtype=np.float32)
#      72 self._ensure_obs_space(obs)
#
# ...
