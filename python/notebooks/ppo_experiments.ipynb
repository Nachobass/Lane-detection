# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # PPO on Unity Lane Simulator
#
# This notebook connects to the Unity TCP bridge and trains PPO while plotting rewards.

# %%
# !pip install stable_baselines3
import os
import numpy as np
import matplotlib.pyplot as plt
from stable_baselines3 import PPO
import sys, os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from rl_bridge.envs import make_env, UnityLaneEnv

HOST = "127.0.0.1"
# HOST = "localhost"
PORT = 5555
LOGDIR = "runs/ppo_lane"
TIMESTEPS = 50_000

os.makedirs(LOGDIR, exist_ok=True)
import socket
env = UnityLaneEnv(host=HOST, port=PORT) #make_env(HOST, PORT)
obs, _ = env.reset()
print("Obs shape:", obs.shape)

model = PPO(
    "MlpPolicy", env, verbose=1, tensorboard_log=LOGDIR,
    n_steps=1024, batch_size=256, gae_lambda=0.95, gamma=0.995, n_epochs=10,
    learning_rate=3e-4, clip_range=0.2,
)

rewards = []

def callback(_locals, _globals):
    # placeholder; SB3 callbacks differ here when using learn()
    return True

model.learn(total_timesteps=TIMESTEPS)

env.close()
print("Training finished.")
# Out:
# Connecting to 127.0.0.1:5555
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 19
#      17 import socket
#      18 env = UnityLaneEnv(host=HOST, port=PORT) #make_env(HOST, PORT)
# ---> 19 obs, _ = env.reset()
#      20 print("Obs shape:", obs.shape)
#      22 model = PPO(
#      23     "MlpPolicy", env, verbose=1, tensorboard_log=LOGDIR,
#      24     n_steps=1024, batch_size=256, gae_lambda=0.95, gamma=0.995, n_epochs=10,
#      25     learning_rate=3e-4, clip_range=0.2,
#      26 )
#
# File ~/Documents/Escuela/Udesa/3er año/2do semestre/RL/Tps/Lane-detection/python/rl_bridge/envs/unity_lane_env.py:74, in UnityLaneEnv.reset(self, seed, options)
#      72 super().reset(seed=seed)
#      73 self._connect()
# ---> 74 data = self._send({"cmd": "reset"})
#      75 obs = np.array(data["obs"], dtype=np.float32)
#      76 self._ensure_obs_space(obs)
#
# File ~/Documents/Escuela/Udesa/3er año/2do semestre/RL/Tps/Lane-detection/python/rl_bridge/envs/unity_lane_env.py:62, in UnityLaneEnv._send(self, obj)
#      60     raise RuntimeError(f"Bad JSON from Unity: {resp}") from e
#      61 if "error" in data:
# ---> 62     raise RuntimeError(f"Unity error: {data['error']}")
#      63 return data
#
# RuntimeError: Unity error: timeout

# %%
import socket
import json
HOST = "127.0.0.1"
PORT = 5555

curr = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
curr.connect((HOST, PORT))
print("Connected to server")


obj = {"cmd": "reset"}
line = json.dumps(obj, separators=(",", ":"))
curr.send(line)

curr.send
# Out:
# Connected to server
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 13
#      11 obj = {"cmd": "reset"}
#      12 line = json.dumps(obj, separators=(",", ":"))
# ---> 13 curr.send(line)
#      15 curr.send
#
# TypeError: a bytes-like object is required, not 'str'

# %%
import socket
import json

# Crear conexión
#sock = socket.create_connection(("localhost", 5555))
# create socket
sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
sock.connect(("localhost", 5555))
# Mensaje como dict
msg = {"cmd": "reset"}

# Convertir a JSON string
msg_str = json.dumps(msg, separators=(",", ":"))  # {"cmd":"reset"}

# Convertir a bytes y añadir newline
msg_bytes = (msg_str + "\n").encode("utf-8")

# Enviar
sock.sendall(msg_bytes)

# Leer respuesta
resp_bytes = sock.recv(4096)  # máximo 4096 bytes
resp_str = resp_bytes.decode("utf-8")
print("Respuesta:", resp_str)

sock.close()
# Out:
# Respuesta: {"error":"timeout"}
